# %%
import requests
import random
import json
import re
import datetime as dt
from bs4 import BeautifulSoup
from urllib.parse import unquote
from headers import headers_list

# %% [markdown]
# ## Channel info

# %%
def get_channel_info(channel_id):
    base_url = f'https://www.youtube.com/channel/{channel_id}/about'
    page = requests.get(base_url, headers=random.choice(headers_list))
    if page.status_code != 200:
        print(page, page.reason)
        return
    soup = BeautifulSoup(page.content, 'html.parser')
    json_text = str(soup.find_all('script')).split('var ytInitialData = ')[-1].split(';</script>')[0]
    res = json.loads(json_text)
    # Get content
    content = None
    for con in res['contents']['twoColumnBrowseResultsRenderer']['tabs']:
        if 'tabRenderer' not in con:
            continue
        if 'content' in con['tabRenderer']:
            content = con['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']\
                ['contents'][0]['channelAboutFullMetadataRenderer']
    if content is None:
        return
    return {
        'id': content['channelId'],
        'title': get_simple_text(content, 'title'),
        'description': get_simple_text(content, 'description'),
        'country': get_simple_text(content, 'country'),
        'url': content['canonicalChannelUrl'],
        'join_date': get_join_date(content),
        'view_count': get_view_count(content),
        'links': get_links(content)
    }


def get_simple_text(content, info):
    try:
        return content[info]['simpleText']
    except:
        return None

def get_view_count(content):
    try:
        view_count = content['viewCountText']['simpleText']
        view_count = view_count.split()[0].replace(',', '')
        return int(view_count)
    except:
        return None

def get_join_date(content):
    try:
        join_date = content['joinedDateText']['runs'][-1]['text']
        return dt.datetime.strptime(join_date, '%d %b %Y').strftime('%Y-%m-%d')
    except:
        return None

def get_links(content):
    links = {}
    for con in content['primaryLinks']:
        try:
            title = con['title']['simpleText']
            url = con['navigationEndpoint']['urlEndpoint']['url']
            url = unquote(url).split('q=')[-1]
            links[title] = url
        except:
            pass
    return links

# %% [markdown]
# ## Channel videos

# %%
def get_channel_videos(channel_id):
    base_url = f'https://www.youtube.com/channel/{channel_id}/videos?view=0&sort=p&flow=grid'
    page = requests.get(base_url, headers=random.choice(headers_list))
    if page.status_code != 200:
        print(page, page.reason)
        return
    soup = BeautifulSoup(page.content, 'html.parser')
    json_text = str(soup.find_all('script')).split('var ytInitialData = ')[-1].split(';</script>')[0]
    res = json.loads(json_text)
    tabs = res['contents']['twoColumnBrowseResultsRenderer']['tabs']
    contents = tabs[1]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']\
        ['contents'][0]['gridRenderer']['items']
    videos = []
    for content in contents:
        if 'gridVideoRenderer' not in content:
            continue
        content = content['gridVideoRenderer']
        videos.append({
            'video_id': get_video_id(content),
            'title': get_title(content),
            'published_time': get_published_time(content),
            'view_count': get_view_count(content),
            'url': get_url(content),
            'length': get_length(content),
        })
    return videos


def get_video_id(content):
    try:
        return content['videoId']
    except:
        return None

def get_title(content):
    try:
        return content['title']['runs'][0]['text']
    except:
        return None

def get_published_time(content):
    try:
        return content['publishedTimeText']['simpleText']
    except:
        return None
    
def get_view_count(content):
    try:
        view_count = content['viewCountText']['simpleText']
        view_count = view_count.split(' views')[0].replace(',', '')
        return int(view_count)
    except:
        return None
    
def get_url(content):
    try:
        url = content['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
        return 'https://www.youtube.com' + url
    except:
        return None

def get_length(content):
    try:
        return content['thumbnailOverlays'][0]['thumbnailOverlayTimeStatusRenderer']['text']['simpleText']
    except:
        return None

# %% [markdown]
# ## Examples

# %%
get_channel_info('UCBwmMxybNva6P_5VmxjzwqA')
# Out:
# {'id': 'UCBwmMxybNva6P_5VmxjzwqA',
#  'title': 'Apna College',
#  'description': 'Hey guys, welcome to this new channel - Apna College. Here Shradha Didi and I(your Aman Bhaiya) will help you in finding your right college, career options, soft skills and will also help you learn to code. \nChalo Phodte hain!\nFeel free to contact Shradha Didi for Seminars, Hackathons & Collaborations at the given email id below.\n\n\n',
#  'country': None,
#  'url': 'http://www.youtube.com/c/ApnaCollegeOfficial',
#  'join_date': None,
#  'view_count': 179100918,
#  'links': {'Facebook': 'https://www.facebook.com/amandhattarwal',
#   'Twitter': 'https://www.twitter.com/amandhattarwal',
#   'Instagram': 'https://www.instagram.com/dhattarwalaman'}}

# %%
get_channel_videos('UCBwmMxybNva6P_5VmxjzwqA')
# Out:
# [{'video_id': 'VVvVxMOrh14',
#   'title': 'Ab India seekhega Coding ❤️',
#   'published_time': '1 month ago',
#   'view_count': 4772309,
#   'url': 'https://www.youtube.com/shorts/VVvVxMOrh14',
#   'length': 'SHORTS'},
#  {'video_id': 'z9bZufPHFLU',
#   'title': '1. Introduction to C++ | Data Structures and Algorithms | College Placement Course | Lecture 1',
#   'published_time': '1 year ago',
#   'view_count': 4532608,
#   'url': 'https://www.youtube.com/watch?v=z9bZufPHFLU',
#   'length': '26:03'},
#  {'video_id': 'hIiz8Km2tpo',
#   'title': '5 Tricks of Google Search',
#   'published_time': '2 months ago',
#   'view_count': 4233174,
#   'url': 'https://www.youtube.com/shorts/hIiz8Km2tpo',
#   'length': 'SHORTS'},
#  {'video_id': '_N6j8HXPt2U',
#   'title': '4 Years of Coding in 4 Minutes - A Short Movie',
#   'published_time': '4 months ago',
#   'view_count': 3823814,
#   'url': 'https://www.youtube.com/watch?v=_N6j8HXPt2U',
#   'length': '3:49'},
#  {'video_id': 'k2oGoqxRLaw',
#   'title': 'Watch this before buying Laptop | Best Budget Laptops and Performance Laptops for all students',
#   'published_time': '1 year ago',
#   'view_count': 3760775,
#   'url': 'https://www.youtube.com/watch?v=k2oGoqxRLaw',
#   'length': '22:01'},
#  {'video_id': 'u49MZH-FFa4',
#   'title': '5 Top Skills to Learn in College',
#   'published_time': '6 months ago',
#   'view_count': 3565478,
#   'url': 'https://www.youtube.com/shorts/u49MZH-FFa4',
#   'length': 'SHORTS'},
#  {'video_id': 'KUv_AAUea7E',
#   'title': 'The 90 Minute Rule for better Sleep!',
#   'published_time': '3 months ago',
#   'view_count': 3541955,
#   'url': 'https://www.youtube.com/shorts/KUv_AAUea7E',
#   'length': 'SHORTS'},
#  {'video_id': 'KWEwNfFrrk4',
#   'title': 'C++, Java or Python? Which language is best for College Placements in India',
#   'published_time': '1 year ago',
#   'view_count': 3017281,
#   'url': 'https://www.youtube.com/shorts/KWEwNfFrrk4',
#   'length': 'SHORTS'},
#  {'video_id': 'irqbmMNs2Bo',
#   'title': 'C Language Tutorial for Beginners (with Notes & Practice Questions)',
#   'published_time': '3 months ago',
#   'view_count': 2606876,
#   'url': 'https://www.youtube.com/watch?v=irqbmMNs2Bo',
#   'length': '10:32:07'},
#  {'video_id': 'yRpLlJmRo2w',
#   'title': 'Introduction to Java Language | Lecture 1 | Complete Placement Course',
#   'published_time': '8 months ago',
#   'view_count': 2563279,
#   'url': 'https://www.youtube.com/watch?v=yRpLlJmRo2w',
#   'length': '18:46'},
#  {'video_id': 'l1EssrLxt7E',
#   'title': "Introduction to Web Development | World's most premium Web Development Course | Lecture 0 (Reupload)",
#   'published_time': '1 year ago',
#   'view_count': 2522407,
#   'url': 'https://www.youtube.com/watch?v=l1EssrLxt7E',
#   'length': '11:08'},
#  {'video_id': 'hzdc6NIMdTY',
#   'title': '3 Tips for taking Notes',
#   'published_time': '3 months ago',
#   'view_count': 2255239,
#   'url': 'https://www.youtube.com/shorts/hzdc6NIMdTY',
#   'length': 'SHORTS'},
#  {'video_id': 'X-cdWlx7hQI',
#   'title': 'Why is Coding Important?',
#   'published_time': '2 months ago',
#   'view_count': 2266005,
#   'url': 'https://www.youtube.com/shorts/X-cdWlx7hQI',
#   'length': 'SHORTS'},
#  {'video_id': 'Rek0NWPCNOc',
#   'title': 'HTML Course | From Beginners to Advance Level | Lecture 1',
#   'published_time': '1 year ago',
#   'view_count': 1975261,
#   'url': 'https://www.youtube.com/watch?v=Rek0NWPCNOc',
#   'length': '37:55'},
#  {'video_id': 'UmnCZ7-9yDY',
#   'title': 'Java Tutorial for Beginners | Learn Java in 2 Hours',
#   'published_time': '11 months ago',
#   'view_count': 1883180,
#   'url': 'https://www.youtube.com/watch?v=UmnCZ7-9yDY',
#   'length': '2:04:35'},
#  {'video_id': 'vLqTf2b6GZw',
#   'title': 'Python Tutorial for Beginners | Learn Python in 1.5 Hours',
#   'published_time': '6 months ago',
#   'view_count': 1818199,
#   'url': 'https://www.youtube.com/watch?v=vLqTf2b6GZw',
#   'length': '1:17:12'},
#  {'video_id': 'rFxlfWO7CWk',
#   'title': 'Biggest Startup Fraud',
#   'published_time': '1 month ago',
#   'view_count': 1714241,
#   'url': 'https://www.youtube.com/shorts/rFxlfWO7CWk',
#   'length': 'SHORTS'},
#  {'video_id': '0yn7irrHzM8',
#   'title': 'VS Code Installation for C++ in Windows | Step by step process explanation',
#   'published_time': '1 year ago',
#   'view_count': 1679712,
#   'url': 'https://www.youtube.com/watch?v=0yn7irrHzM8',
#   'length': '10:15'},
#  {'video_id': 'wioAFuHzcao',
#   'title': 'I Resigned as a Software Engineer from Microsoft',
#   'published_time': '8 months ago',
#   'view_count': 1607635,
#   'url': 'https://www.youtube.com/watch?v=wioAFuHzcao',
#   'length': '6:29'},
#  {'video_id': 'tGDQuWDk2Z8',
#   'title': 'iPad | Should you buy it?',
#   'published_time': '6 months ago',
#   'view_count': 1571401,
#   'url': 'https://www.youtube.com/shorts/tGDQuWDk2Z8',
#   'length': 'SHORTS'},
#  {'video_id': 'pPb8RYMHbbA',
#   'title': 'This company gives FREE cookies',
#   'published_time': '5 months ago',
#   'view_count': 1571662,
#   'url': 'https://www.youtube.com/shorts/pPb8RYMHbbA',
#   'length': 'SHORTS'},
#  {'video_id': 'RNwMeijExjg',
#   'title': 'All about Hacking | What to study, Packages, Job Opporutnities | Simply Explained',
#   'published_time': '1 year ago',
#   'view_count': 1515820,
#   'url': 'https://www.youtube.com/watch?v=RNwMeijExjg',
#   'length': '9:32'},
#  {'video_id': 'zlZ_dupXxE0',
#   'title': 'How to Hack Password?',
#   'published_time': '3 months ago',
#   'view_count': 1518080,
#   'url': 'https://www.youtube.com/watch?v=zlZ_dupXxE0',
#   'length': '4:33'},
#  {'video_id': 'jfC_Ih_hYIA',
#   'title': 'One Mantra for today’s Digital Age | for students',
#   'published_time': '7 months ago',
#   'view_count': 1487609,
#   'url': 'https://www.youtube.com/shorts/jfC_Ih_hYIA',
#   'length': 'SHORTS'},
#  {'video_id': '16uXCDeRvMU',
#   'title': 'Students after studying coding from Apna College ❤️ | Motivational Memes',
#   'published_time': '1 year ago',
#   'view_count': 1463517,
#   'url': 'https://www.youtube.com/watch?v=16uXCDeRvMU',
#   'length': '0:26'},
#  {'video_id': 'eKqY-oP1d_Y',
#   'title': 'How to Start Coding? Learn Programming for Beginners',
#   'published_time': '4 months ago',
#   'view_count': 1385550,
#   'url': 'https://www.youtube.com/watch?v=eKqY-oP1d_Y',
#   'length': '11:05'},
#  {'video_id': 'TpN9XEStbNQ',
#   'title': 'How to protect your eyes from Mobile/Laptop ?',
#   'published_time': '1 month ago',
#   'view_count': 1378677,
#   'url': 'https://www.youtube.com/shorts/TpN9XEStbNQ',
#   'length': 'SHORTS'},
#  {'video_id': 'MvEBc_60OmM',
#   'title': 'Software Engineers | 3 Things you didn’t know',
#   'published_time': '6 months ago',
#   'view_count': 1265313,
#   'url': 'https://www.youtube.com/shorts/MvEBc_60OmM',
#   'length': 'SHORTS'},
#  {'video_id': 'cnT1oW5_ePM',
#   'title': '2.1 Data Types & Type Modifiers | Data Structures & Algorithms Course in C++ | Lecture 2.1',
#   'published_time': '1 year ago',
#   'view_count': 1248785,
#   'url': 'https://www.youtube.com/watch?v=cnT1oW5_ePM',
#   'length': '11:09'},
#  {'video_id': 'lCRFpaykm9I',
#   'title': '3 Tips to have More Confidence | Simply Explained',
#   'published_time': '6 months ago',
#   'view_count': 1232697,
#   'url': 'https://www.youtube.com/shorts/lCRFpaykm9I',
#   'length': 'SHORTS'}]

# %%
get_channel_info('UCLpovxJVLBZrXJGCymB6LYw')
# Out:
# {'id': 'UCLpovxJVLBZrXJGCymB6LYw',
#  'title': 'Namanh Kapur',
#  'description': "Hi! 👋 Welcome to my channel — I'm a 23 year old, recent graduate working at a high growth startup! Follow along for insights into the tech industry, all things startup, and what to expect as a recent-grad remote software engineer. I also dabble in sketch-comedy and investing. Thanks for being here!\n \nMilestones:\n[2022]\nJan 05 -- 0 subs (Video #1)\nFeb 07 -- 100 subs\nFeb 25 -- 500 subs\nMar 22 -- 1,000 subs\nMar 30 -- 5,000 subs\nApr 01 -- 10,000 subs\nApr 23 -- 25,000 subs\n",
#  'country': 'United States',
#  'url': 'http://www.youtube.com/c/NamanhKapur',
#  'join_date': None,
#  'view_count': 2323475,
#  'links': {'namanhkapur.com': 'namanhkapur.com'}}

# %%
get_channel_videos('UCLpovxJVLBZrXJGCymB6LYw')
# Out:
# [{'video_id': 'k9WqpQp8VSU',
#   'title': 'How I Would Learn To Code (If I Could Start Over)',
#   'published_time': '1 month ago',
#   'view_count': 1032465,
#   'url': 'https://www.youtube.com/watch?v=k9WqpQp8VSU',
#   'length': '13:43'},
#  {'video_id': 'dHN_tlBEt2c',
#   'title': "I'm Not The Best Programmer",
#   'published_time': '2 months ago',
#   'view_count': 552271,
#   'url': 'https://www.youtube.com/watch?v=dHN_tlBEt2c',
#   'length': '8:52'},
#  {'video_id': 'TURmIFBcgVY',
#   'title': 'A Day in the Life of a Software Engineer in San Francisco',
#   'published_time': '2 months ago',
#   'view_count': 170153,
#   'url': 'https://www.youtube.com/watch?v=TURmIFBcgVY',
#   'length': '5:55'},
#  {'video_id': 'bu1blwFrk70',
#   'title': 'A Day in the Life of a Software Engineer in New York City',
#   'published_time': '2 months ago',
#   'view_count': 163640,
#   'url': 'https://www.youtube.com/watch?v=bu1blwFrk70',
#   'length': '7:52'},
#  {'video_id': 'PrS2e1HSP2U',
#   'title': "10 Years of Coding: Everything I've Ever Learned",
#   'published_time': '3 months ago',
#   'view_count': 129320,
#   'url': 'https://www.youtube.com/watch?v=PrS2e1HSP2U',
#   'length': '13:31'},
#  {'video_id': 'CadQhoBUvlY',
#   'title': 'How To Be a Better Problem Solver',
#   'published_time': '2 weeks ago',
#   'view_count': 39629,
#   'url': 'https://www.youtube.com/watch?v=CadQhoBUvlY',
#   'length': '10:36'},
#  {'video_id': 'ZxwdLyHLnjY',
#   'title': 'Day In The Life of a Software Engineer at a Startup',
#   'published_time': '4 months ago',
#   'view_count': 37551,
#   'url': 'https://www.youtube.com/watch?v=ZxwdLyHLnjY',
#   'length': '3:42'},
#  {'video_id': 'mea5HZHekpw',
#   'title': 'The Software Engineering Ladder Explained',
#   'published_time': '11 days ago',
#   'view_count': 41658,
#   'url': 'https://www.youtube.com/watch?v=mea5HZHekpw',
#   'length': '10:40'},
#  {'video_id': '5O71rJBWP5M',
#   'title': 'Remote Software Engineers Be Like (Pt. 1)',
#   'published_time': '3 months ago',
#   'view_count': 27850,
#   'url': 'https://www.youtube.com/watch?v=5O71rJBWP5M',
#   'length': '3:58'},
#  {'video_id': '-CcYgIcN7X4',
#   'title': 'Remote Software Engineers Be Like (Pt. 2)',
#   'published_time': '3 months ago',
#   'view_count': 24716,
#   'url': 'https://www.youtube.com/watch?v=-CcYgIcN7X4',
#   'length': '4:21'},
#  {'video_id': 'Mv3vHn_yLuo',
#   'title': 'Rejecting Internship Offers From Microsoft & Facebook',
#   'published_time': '2 months ago',
#   'view_count': 21660,
#   'url': 'https://www.youtube.com/watch?v=Mv3vHn_yLuo',
#   'length': '9:35'},
#  {'video_id': 'rTqibt4vbOA',
#   'title': 'Software Engineers Oncall Be Like',
#   'published_time': '1 month ago',
#   'view_count': 19204,
#   'url': 'https://www.youtube.com/watch?v=rTqibt4vbOA',
#   'length': '6:15'},
#  {'video_id': 'opv7gkGwjSw',
#   'title': 'Why I Studied Computer Science (And You Should Too)',
#   'published_time': '1 month ago',
#   'view_count': 18147,
#   'url': 'https://www.youtube.com/watch?v=opv7gkGwjSw',
#   'length': '8:44'},
#  {'video_id': 'o0aLQRwxIWY',
#   'title': 'I Only Work 4 DAYS A WEEK as a SOFTWARE ENGINEER @ BOLT',
#   'published_time': '4 months ago',
#   'view_count': 14347,
#   'url': 'https://www.youtube.com/watch?v=o0aLQRwxIWY',
#   'length': '8:07'},
#  {'video_id': 'VoZyN4nLVDI',
#   'title': 'Tech Offsite in San Francisco (Bolt)',
#   'published_time': '1 month ago',
#   'view_count': 10793,
#   'url': 'https://www.youtube.com/watch?v=VoZyN4nLVDI',
#   'length': '7:08'},
#  {'video_id': '8u45QMEn1o4',
#   'title': 'How To Create a Personal Website on Notion',
#   'published_time': '3 months ago',
#   'view_count': 8617,
#   'url': 'https://www.youtube.com/watch?v=8u45QMEn1o4',
#   'length': '8:25'},
#  {'video_id': 'agHgLLrgH-c',
#   'title': 'How I Became a Software Engineer',
#   'published_time': '2 weeks ago',
#   'view_count': 5708,
#   'url': 'https://www.youtube.com/watch?v=agHgLLrgH-c',
#   'length': '46:40'},
#  {'video_id': 'uSqEgL0wxOk',
#   'title': 'Automating Every $0.01 Of My Software Engineer Paycheck',
#   'published_time': '4 months ago',
#   'view_count': 4836,
#   'url': 'https://www.youtube.com/watch?v=uSqEgL0wxOk',
#   'length': '5:14'},
#  {'video_id': 'D0WXVilQ0Oc',
#   'title': 'Software Engineering Benefits That Actually Matter',
#   'published_time': '4 months ago',
#   'view_count': 4223,
#   'url': 'https://www.youtube.com/watch?v=D0WXVilQ0Oc',
#   'length': '3:46'},
#  {'video_id': '8NbE7UzVYms',
#   'title': 'Summer in Seattle | Microsoft 2018 (Extended Cut)',
#   'published_time': '3 years ago',
#   'view_count': 3287,
#   'url': 'https://www.youtube.com/watch?v=8NbE7UzVYms',
#   'length': '7:06'},
#  {'video_id': '0HtjEY64LzU',
#   'title': "Don't Let Others Invest YOUR Money, HERE'S WHY | Personal Finance",
#   'published_time': '5 months ago',
#   'view_count': 3123,
#   'url': 'https://www.youtube.com/watch?v=0HtjEY64LzU',
#   'length': '5:37'},
#  {'video_id': 'tTbK3HnBFLo',
#   'title': '5 Things to Know Before Software Engineer Recruiting',
#   'published_time': '4 months ago',
#   'view_count': 2823,
#   'url': 'https://www.youtube.com/watch?v=tTbK3HnBFLo',
#   'length': '5:01'},
#  {'video_id': '9-PIFz3KmrE',
#   'title': 'The 5-Part Guide to Getting That Dream Offer | Software Engineering',
#   'published_time': '1 day ago',
#   'view_count': 4689,
#   'url': 'https://www.youtube.com/watch?v=9-PIFz3KmrE',
#   'length': '15:35'},
#  {'video_id': 'VvYbMospBPE',
#   'title': 'Heavy Metal in Africa',
#   'published_time': '5 years ago',
#   'view_count': 2083,
#   'url': 'https://www.youtube.com/watch?v=VvYbMospBPE',
#   'length': '7:06'},
#  {'video_id': 'vaN2MfmwQ5A',
#   'title': 'Summer in SF | Gusto 2019',
#   'published_time': '2 years ago',
#   'view_count': 1777,
#   'url': 'https://www.youtube.com/watch?v=vaN2MfmwQ5A',
#   'length': '3:14'},
#  {'video_id': 'ZCE2GCPDuJA',
#   'title': 'Summer in Seattle | Microsoft 2018',
#   'published_time': '3 years ago',
#   'view_count': 1479,
#   'url': 'https://www.youtube.com/watch?v=ZCE2GCPDuJA',
#   'length': '3:00'},
#  {'video_id': '5y9zt9eLlYg',
#   'title': 'Rice Launch Challenge: Perfect Fit',
#   'published_time': '2 years ago',
#   'view_count': 1147,
#   'url': 'https://www.youtube.com/watch?v=5y9zt9eLlYg',
#   'length': '1:00'}]

# %%
get_channel_info('UCsvqVGtbbyHaMoevxPAq9Fg')
# Out:
# {'id': 'UCsvqVGtbbyHaMoevxPAq9Fg',
#  'title': 'Simplilearn',
#  'description': 'Simplilearn is the world’s #1 online Bootcamp and one of the world’s leading certification training providers. Based in San Francisco, California, and Bangalore, India, we provide training in areas where technologies and best practices are changing rapidly, and the demand for qualified candidates significantly exceeds the supply. We have trained over 3,000,000 professionals, have over 2000 qualified trainers on board, and offer over 400 courses with 40 plus global accreditations. With live instructions from leading experts, interactive labs & projects, peer-to-peer collaboration, on-demand lessons, and 24/7 learning support, we provide learners with a comprehensive curriculum at a fraction of the cost of an on-campus program. \n\nFor more information, visit https://www.simplilearn.com/\nOur FREE courses via SkillUp by Simplilearn now come with Completion Certificates! :https://www.simplilearn.com/skillup-free-online-courses\n',
#  'country': 'United States',
#  'url': 'http://www.youtube.com/c/SimplilearnOfficial',
#  'join_date': None,
#  'view_count': 214582536,
#  'links': {'Explore Free Courses': 'https://www.simplilearn.com/skillup-free-online-courses?utm_campaign=SkillUp&utm_medium=Homepage&utm_source=youtube',
#   'Subscribe Now!': 'https://www.youtube.com/user/Simplilearn?sub_confirmation=1',
#   'Visit our website': 'https://www.simplilearn.com/?utm_campaign=Simplilearn&utm_medium=Homepage&utm_source=youtube',
#   'Facebook': 'https://www.facebook.com/Simplilearn',
#   'Twitter': 'https://twitter.com/simplilearn',
#   'LinkedIn': 'http://www.linkedin.com/company/simplilearn',
#   'Google+': 'https://plus.google.com/b/109241443194127567538/+simplilearn/posts?pageId=109241443194127567538'}}

# %%
get_channel_videos('UCsvqVGtbbyHaMoevxPAq9Fg')
# Out:
# [{'video_id': 'VWJMlG_5Pdk',
#   'title': 'Ambition #CannotBeLockedDown \u200b| Nikhil Got His Dream Job | And You? | Upskill Now With Simplilearn',
#   'published_time': '8 months ago',
#   'view_count': 18202449,
#   'url': 'https://www.youtube.com/watch?v=VWJMlG_5Pdk',
#   'length': '0:45'},
#  {'video_id': 'qkdQGxpiymQ',
#   'title': '#JobGuaranteed | Simplilearn Job Guarantee Programs | Upskill. Get A Job. Guaranteed | SabkoPataaHai',
#   'published_time': '4 months ago',
#   'view_count': 12488159,
#   'url': 'https://www.youtube.com/watch?v=qkdQGxpiymQ',
#   'length': '0:31'},
#  {'video_id': '5nz9xepgVJo',
#   'title': '#JobGuaranteed | Simplilearn Job Guarantee Programs | Upskill. Get A Job. Guaranteed | SabkoPataaHai',
#   'published_time': '4 months ago',
#   'view_count': 11831890,
#   'url': 'https://www.youtube.com/watch?v=5nz9xepgVJo',
#   'length': '0:31'},
#  {'video_id': 'MSKZxL2D4Uo',
#   'title': 'Simplilearn Job Guarantee Programs - Your Job Is Surely Guaranteed! 😎 | #GuaranteeKaSeason',
#   'published_time': '1 month ago',
#   'view_count': 7615551,
#   'url': 'https://www.youtube.com/watch?v=MSKZxL2D4Uo',
#   'length': '0:20'},
#  {'video_id': 'GaqCZ4FxFKc',
#   'title': 'Simplilearn Job Guarantee Programs - Your Job Is Surely Guaranteed! 😎 | #JobGuaranteed',
#   'published_time': '1 month ago',
#   'view_count': 6561214,
#   'url': 'https://www.youtube.com/watch?v=GaqCZ4FxFKc',
#   'length': '0:26'},
#  {'video_id': 'ukzFI9rgwfU',
#   'title': 'Machine Learning Basics | What Is Machine Learning? | Introduction To Machine Learning | Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 3157103,
#   'url': 'https://www.youtube.com/watch?v=ukzFI9rgwfU',
#   'length': '7:52'},
#  {'video_id': 'Osa53-RYBk4',
#   'title': 'How To Introduce Yourself In Interview | Self Introduction In Interview For Freshers | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 2741134,
#   'url': 'https://www.youtube.com/watch?v=Osa53-RYBk4',
#   'length': '5:39'},
#  {'video_id': 'X3paOmcrTjQ',
#   'title': 'Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 2704545,
#   'url': 'https://www.youtube.com/watch?v=X3paOmcrTjQ',
#   'length': '4:38'},
#  {'video_id': 'nU-IIXBWlS4',
#   'title': 'Digital Marketing Course Part - 1 🔥| Digital Marketing Tutorial For Beginners | Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 2395354,
#   'url': 'https://www.youtube.com/watch?v=nU-IIXBWlS4',
#   'length': '10:50:20'},
#  {'video_id': 'OYRkIGaP80M',
#   'title': 'SEO Tutorial For Beginners  | SEO Full Course | Search Engine Optimization Tutorial | Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 1799379,
#   'url': 'https://www.youtube.com/watch?v=OYRkIGaP80M',
#   'length': '8:26:47'},
#  {'video_id': 'r4YIdn2eTm4',
#   'title': 'AWS In 10 Minutes | AWS Tutorial For Beginners | AWS Training Video | AWS Tutorial | Simplilearn',
#   'published_time': '4 years ago',
#   'view_count': 1722114,
#   'url': 'https://www.youtube.com/watch?v=r4YIdn2eTm4',
#   'length': '9:12'},
#  {'video_id': 'bixR-KIJKYM',
#   'title': 'Digital Marketing In 5 Minutes | What Is Digital Marketing? | Learn Digital Marketing | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 1713020,
#   'url': 'https://www.youtube.com/watch?v=bixR-KIJKYM',
#   'length': '5:25'},
#  {'video_id': 'yubzJw0uiE4',
#   'title': 'Blockchain In 7 Minutes | What Is Blockchain | Blockchain Explained|How Blockchain Works|Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 1604364,
#   'url': 'https://www.youtube.com/watch?v=yubzJw0uiE4',
#   'length': '7:03'},
#  {'video_id': '4EDYfSl-fmc',
#   'title': 'Six Sigma In 9 Minutes | What Is Six Sigma? | Six Sigma Explained | Six Sigma Training | Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 1564244,
#   'url': 'https://www.youtube.com/watch?v=4EDYfSl-fmc',
#   'length': '8:59'},
#  {'video_id': '3Arj5zlUPG4',
#   'title': 'What Is Azure? | Microsoft Azure Tutorial For Beginners | Microsoft Azure Training | Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 1430781,
#   'url': 'https://www.youtube.com/watch?v=3Arj5zlUPG4',
#   'length': '10:34'},
#  {'video_id': 'RWgW-CgdIk0',
#   'title': 'Cloud Computing Tutorial for Beginners | Cloud Computing Explained | Cloud Computing | Simplilearn',
#   'published_time': '4 years ago',
#   'view_count': 1223259,
#   'url': 'https://www.youtube.com/watch?v=RWgW-CgdIk0',
#   'length': '24:38'},
#  {'video_id': 'NNQLJcJEzv0',
#   'title': 'NFT Explained In 5 Minutes | What Is NFT? - Non Fungible Token | NFT Crypto Explained | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 1176795,
#   'url': 'https://www.youtube.com/watch?v=NNQLJcJEzv0',
#   'length': '4:51'},
#  {'video_id': 'dgjZ2fHg4y4',
#   'title': 'Cryptocurrency Full Course | Cryptocurrency For Beginners | Cryptocurrency Explained | Simplilearn',
#   'published_time': 'Streamed 10 months ago',
#   'view_count': 1169967,
#   'url': 'https://www.youtube.com/watch?v=dgjZ2fHg4y4',
#   'length': '2:40:16'},
#  {'video_id': 's2HCrhNVfak',
#   'title': 'Lean Six Sigma In 8 Minutes | What Is Lean Six Sigma? | Lean Six Sigma Explained | Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 1096452,
#   'url': 'https://www.youtube.com/watch?v=s2HCrhNVfak',
#   'length': '8:08'},
#  {'video_id': 'IrgGmaeYmdM',
#   'title': 'Top 10 Technologies To Learn In 2022 | Trending Technologies In 2022 | Simplilearn',
#   'published_time': '6 months ago',
#   'view_count': 1084127,
#   'url': 'https://www.youtube.com/watch?v=IrgGmaeYmdM',
#   'length': '11:03'},
#  {'video_id': 'rmDXEh7hi4w',
#   'title': 'Top 10 Certifications For 2022 | Highest Paying Certifications | Best IT Certifications |Simplilearn',
#   'published_time': '7 months ago',
#   'view_count': 1067438,
#   'url': 'https://www.youtube.com/watch?v=rmDXEh7hi4w',
#   'length': '12:21'},
#  {'video_id': 'W-9jIVm0-p8',
#   'title': 'Top 10 Certifications For 2021 | Highest Paying Certifications | Best IT Certifications |Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 1057076,
#   'url': 'https://www.youtube.com/watch?v=W-9jIVm0-p8',
#   'length': '8:47'},
#  {'video_id': 'PlHnamdwGmw',
#   'title': 'Cyber Security Full Course - Learn Cyber Security In 8 Hours | Cyber Security Training |Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 1030933,
#   'url': 'https://www.youtube.com/watch?v=PlHnamdwGmw',
#   'length': '8:10:43'},
#  {'video_id': 'M988_fsOSWo',
#   'title': 'Cloud Computing In 6 Minutes | What Is Cloud Computing? | Cloud Computing Explained | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 983635,
#   'url': 'https://www.youtube.com/watch?v=M988_fsOSWo',
#   'length': '6:24'},
#  {'video_id': 'inWWhr5tnEA',
#   'title': 'Cyber Security In 7 Minutes | What Is Cyber Security: How It Works? | Cyber Security | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 967372,
#   'url': 'https://www.youtube.com/watch?v=inWWhr5tnEA',
#   'length': '7:07'},
#  {'video_id': 'P-PCoZzy4l8',
#   'title': 'Facebook Ads Course In 3 Hours  | Facebook Ads Tutorial | Facebook Marketing Course | Simplilearn',
#   'published_time': '1 year ago',
#   'view_count': 952961,
#   'url': 'https://www.youtube.com/watch?v=P-PCoZzy4l8',
#   'length': '2:38:16'},
#  {'video_id': 'wTbrk0suwbg',
#   'title': 'Artificial Intelligence & the Future - Rise of AI (Elon Musk, Bill Gates, Sundar Pichai)|Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 945937,
#   'url': 'https://www.youtube.com/watch?v=wTbrk0suwbg',
#   'length': '4:52'},
#  {'video_id': 'bAyrObl7TYE',
#   'title': 'Big Data In 5 Minutes | What Is Big Data?| Introduction To Big Data |Big Data Explained |Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 933211,
#   'url': 'https://www.youtube.com/watch?v=bAyrObl7TYE',
#   'length': '5:12'},
#  {'video_id': 'Qs0_Qu22v4M',
#   'title': 'SEO Tutorial For Beginners | Learn SEO Step By Step | SEO Tutorial | Advanced SEO 2020 | Simplilearn',
#   'published_time': '3 years ago',
#   'view_count': 894135,
#   'url': 'https://www.youtube.com/watch?v=Qs0_Qu22v4M',
#   'length': '2:31:22'},
#  {'video_id': 'FX322RVNGj4',
#   'title': 'Jenkins Full Course | Jenkins Tutorial For Beginners | Jenkins Tutorial | Simplilearn',
#   'published_time': '2 years ago',
#   'view_count': 870979,
#   'url': 'https://www.youtube.com/watch?v=FX322RVNGj4',
#   'length': '2:56:07'}]
